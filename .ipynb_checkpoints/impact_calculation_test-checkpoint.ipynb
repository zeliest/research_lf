# %%
from climada.hazard.base import Hazard
from climada.hazard.low_flow import LowFlow
from climada.entity import ImpactFunc, ImpactFuncSet
from climada.entity.exposures import Exposures
from climada.engine import Impact
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from climada.engine.cost_benefit import *
from climada.entity.entity_def import Entity
from climada.entity.disc_rates.base import DiscRates
import datetime
from
# Out:
# 2020-06-17 11:55:40,649 - climada - DEBUG - Loading default config file: /home/zelie/Python_projects/climada_python/climada/conf/defaults.conf

# %%
lowflow = LowFlow()
lowflow.read_hdf5('hazards/computed_hazard_h08_gfdl-esm2m.h5')
#lowflow.read_hdf5('hazards/computed_hazard_lpjml_miroc5.h5')
# Out:
# 2020-06-17 12:17:48,434 - climada.hazard.base - INFO - Reading hazards/computed_hazard_h08_gfdl-esm2m.h5

# %%
lowflow.plot_intensity(0)

# %%
lowflow.plot_intensity(0,vmax=365)

# %%
wri_power_plants_path = '/home/zelie/Python_projects/low_flow/data/exposure/global_power_plant_database.csv'


def load_exposure(bbox=[-180, -90, 180, 90], exp_path=wri_power_plants_path, primary_fuel='Nuclear'):
    """load exposure data from CSV
    Here, we use WRI power plant data from
    https://www.wri.org/publication/global-power-plant-database"""
    exp_df = pd.read_csv(exp_path)
    if primary_fuel:
        exp_df = exp_df[exp_df.primary_fuel==primary_fuel]
    # europe:
    exp_df = exp_df[exp_df.longitude>bbox[0]]
    exp_df = exp_df[exp_df.longitude<bbox[2]]
    exp_df = exp_df[exp_df.latitude>bbox[1]]
    exp_df = exp_df[exp_df.latitude<bbox[3]]
    exp_df['gen_mean']=exp_df[["generation_gwh_2013", "generation_gwh_2014", "generation_gwh_2015", "generation_gwh_2016", "generation_gwh_2017"]].mean(axis=1)
    exp_df['value']=exp_df[["gen_mean", "estimated_generation_gwh"]].mean(axis=1)
    # exp_df['value'] = exp_df.capacity_mw # provide value in MegaWatt
    
    #exp_df['latitude'] = 
    #exp_df['longitude'] = 
    exp_df['if_'] = 1
    exp_df['if_LF'] = 1
    # exp_df = exp_df.drop(columns=['country', 'name', 'gppd_idnr',
    #    'latitude', 'longitude', 'primary_fuel', 'owner', 'source', 'url',
    #    'geolocation_source', 'wepp_id', 'year_of_capacity_data',
    #    'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
    #    'generation_gwh_2016', 'generation_gwh_2017',
    #    'estimated_generation_gwh', 'value', 'value_unit', 'if_TC', 'geometry'])
    

    # Generate Exposures from exposure-DataFranme
    exp_df = Exposures(exp_df)
    exp_df.value_unit = 'GWh'
    exp_df.ref_year = 2005
    exp_df.set_geometry_points() # set geometry attribute (shapely Points) from GeoDataFrame from latitude and longitude
    print('\n' + '\x1b[1;03;30;30m' + 'check method logs:' + '\x1b[0m')
    exp_df.check() # puts metadata that has not been assigned
    return exp_df

# %%
exposures = load_exposure()
# Out:
# 2020-06-17 12:20:33,436 - climada.util.coordinates - INFO - Setting geometry points.
#
# check method logs:
# 2020-06-17 12:20:33,445 - climada.entity.exposures.base - INFO - crs set to default value: {'init': 'epsg:4326', 'no_defs': True}
# 2020-06-17 12:20:33,445 - climada.entity.exposures.base - INFO - tag metadata set to default value:  File:
#  Description:
# 2020-06-17 12:20:33,446 - climada.entity.exposures.base - INFO - meta metadata set to default value: None
# 2020-06-17 12:20:33,446 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2020-06-17 12:20:33,446 - climada.entity.exposures.base - INFO - centr_ not set.
# 2020-06-17 12:20:33,447 - climada.entity.exposures.base - INFO - deductible not set.
# 2020-06-17 12:20:33,447 - climada.entity.exposures.base - INFO - cover not set.
# 2020-06-17 12:20:33,448 - climada.entity.exposures.base - INFO - category_id not set.
# 2020-06-17 12:20:33,448 - climada.entity.exposures.base - INFO - region_id not set.

# %%
IF_data = pd.read_csv('IF_data.csv')
hydro = IF_data[IF_data['Focus']=='Hydro']
thermo = IF_data[IF_data['Focus']!='Hydro']


col = {'thermo':'Red', 'hydro':'blue'}

data = {'thermo':thermo,'hydro':hydro}
if_slopes = {}

for h_model in ['matsiro','h08','lpjml']:
    fig, ax = plt.subplots()
    if_slopes[h_model] = {}
    for technology in ['hydro','thermo']:
        n = [0]+list(data[technology][h_model])
        d = [0]+list(data[technology]["_".join(['discharge_reduction',h_model])])

        x0 = np.linspace(0,365*2,100)
        s = np.polyfit(n,d,1)[0]
        if_slopes[h_model][technology] = s
        ax.plot(x0,s*x0,color = col[technology],label=technology)
        ax.scatter(n,d,color = col[technology])
        ax.set_xlabel('Number of days below threshold')
        ax.set_ylabel('Loss')
        ax.legend()
        ax.set_title(" ".join([h_model]))

# %%
def init_IFS(s):
    """define impact function imp_fun and return impact function set (IFS)"""
    x0 = np.linspace(0,365,100)
    imp_fun = ImpactFunc()
    imp_fun.haz_type = 'LF'
    imp_fun.id = 1
    imp_fun.name = 'Low flow business interruption'
    imp_fun.intensity_unit = 'days'
    imp_fun.intensity = x0
    imp_fun.mdd = s*x0
 # loss to annual operation
    imp_fun.paa = imp_fun.intensity * 0 + 1
    # imp_fun.paa[imp_fun.intensity<mdm] = 0
    imp_fun.check()
    IFS = ImpactFuncSet()
    IFS.append(imp_fun)
    return IFS

IFS_lf = init_IFS(if_slopes['lpjml']['thermo'])

# %%
imp_lf = Impact()
imp_lf.calc(exposures, IFS_lf, lowflow)
# Out:
# 2020-06-17 12:20:36,935 - climada.entity.exposures.base - INFO - Matching 198 exposures with 259200 centroids.
# 2020-06-17 12:20:38,109 - climada.engine.impact - INFO - Calculating damage for 180 assets (>0) and 5797 events.

# %%
# impacts on nuclear power plants

imp_lf.plot_hexbin_eai_exposure(pop_name=False)
# Out:
# /home/zelie/Python_projects/climada_python/climada/util/plot.py:311: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()

# %%
print(imp_lf.at_event[:1259].sum()) #2006-2030
# Out:
# 1833902.1936207511

# %%
imp_lf.at_event[4538:].sum() #2075-2099
# Out:
# 3928653.02659179

# %%
(lowflow.intensity>365).nnz/lowflow.intensity.nnz #only 1/1000 events last longer than a year
# Out:
# 0.06711503992076966

# %%
np.max(lowflow.intensity[lowflow.intensity>365])
# Out:
# 11680.0

# %%
test = np.where(lowflow.intensity.data>365)[0]
len(test)
# Out:
# 9425

# %%
#distribution of the intensity of the events lasting more than a year

fig, ax = plt.subplots(1, 1)
ax.hist(np.array(lowflow.intensity[lowflow.intensity>365]).flatten(),bins=300)
# Out:
# (array([1.236e+03, 9.640e+02, 8.130e+02, 6.240e+02, 5.520e+02, 5.060e+02,
#         4.170e+02, 3.600e+02, 2.900e+02, 2.830e+02, 2.230e+02, 2.260e+02,
#         1.840e+02, 1.600e+02, 1.540e+02, 1.660e+02, 1.390e+02, 1.180e+02,
#         1.160e+02, 1.040e+02, 8.700e+01, 7.800e+01, 7.100e+01, 6.200e+01,
#         6.200e+01, 5.300e+01, 4.200e+01, 4.900e+01, 4.900e+01, 4.000e+01,
#         3.600e+01, 3.400e+01, 3.100e+01, 3.100e+01, 3.200e+01, 2.700e+01,
#         2.400e+01, 2.300e+01, 2.300e+01, 3.100e+01, 3.300e+01, 2.600e+01,
#         2.900e+01, 2.000e+01, 2.400e+01, 1.500e+01, 1.500e+01, 1.300e+01,
#         1.200e+01, 1.500e+01, 1.800e+01, 1.900e+01, 2.000e+01, 2.300e+01,
#         1.200e+01, 7.000e+00, 2.500e+01, 1.500e+01, 1.000e+01, 9.000e+00,
#         1.200e+01, 8.000e+00, 1.600e+01, 8.000e+00, 1.500e+01, 1.500e+01,
#         7.000e+00, 8.000e+00, 7.000e+00, 6.000e+00, 1.500e+01, 1.000e+01,
#         7.000e+00, 1.200e+01, 3.000e+00, 4.000e+00, 7.000e+00, 6.000e+00,
#         8.000e+00, 6.000e+00, 1.000e+01, 4.000e+00, 8.000e+00, 5.000e+00,
#         4.000e+00, 3.000e+00, 3.000e+00, 4.000e+00, 5.000e+00, 0.000e+00,
#         6.000e+00, 8.000e+00, 3.000e+00, 1.000e+01, 6.000e+00, 2.000e+00,
#         4.000e+00, 2.000e+00, 7.000e+00, 3.000e+00, 7.000e+00, 4.000e+00,
#         6.000e+00, 6.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 4.000e+00,
#         5.000e+00, 4.000e+00, 4.000e+00, 2.000e+00, 3.000e+00, 4.000e+00,
#         4.000e+00, 1.000e+00, 2.000e+00, 1.000e+00, 3.000e+00, 6.000e+00,
#         2.000e+00, 3.000e+00, 1.000e+00, 3.000e+00, 2.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 4.000e+00, 2.000e+00, 3.000e+00, 1.000e+00,
#         2.000e+00, 1.000e+00, 2.000e+00, 4.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00, 4.000e+00, 1.000e+00, 3.000e+00, 2.000e+00,
#         4.000e+00, 1.000e+00, 3.000e+00, 6.000e+00, 3.000e+00, 1.000e+00,
#         5.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 3.000e+00, 2.000e+00,
#         4.000e+00, 2.000e+00, 1.000e+00, 1.000e+00, 2.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00,